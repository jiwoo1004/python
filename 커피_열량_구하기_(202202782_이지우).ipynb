# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwoo1004/python/blob/main/%EC%BB%A4%ED%94%BC_%EC%97%B4%EB%9F%89_%EA%B5%AC%ED%95%98%EA%B8%B0_(202202782_%EC%9D%B4%EC%A7%80%EC%9A%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#202202782 이지우
from google.colab import files

myfile = files.upload()

import pandas as pd

df = pd.read_csv('caffeine.csv')

df
# Out:
#      <input type="file" id="files-391e3848-b841-42f6-9248-19d447961c70" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-391e3848-b841-42f6-9248-19d447961c70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="type", y ="Calories", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Calories", data = df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Calories", data = df, kde = 'true')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Calories", data = df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="type", y="Calories", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="type", y="Calories", data=df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="type", y ="Volume (ml)", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Volume (ml)", data = df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Volume (ml)", data = df, kde = 'true')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Volume (ml)", data = df,hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="type", y="Volume (ml)", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="type", y="Volume (ml)", data=df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="type", y ="Caffeine (mg)", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Caffeine (mg)", data = df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Caffeine (mg)", data = df, kde ='true')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})



sns.histplot( x= "Caffeine (mg)", data = df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="type", y="Caffeine (mg)", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="type", y="Caffeine (mg)", data=df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="Volume (ml)", y ="Caffeine (mg)", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="Volume (ml)", y="Caffeine (mg)", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="Calories", y ="Caffeine (mg)", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})


sns.scatterplot(x="Volume (ml)", y ="Calories", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="Calories", y="Caffeine (mg)", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.barplot(x="Calories", y="Volume (ml)", data =df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="Volume (ml)", y="Caffeine (mg)", data=df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="Calories", y="Volume (ml)", data=df)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('caffeine.csv')

sns.set_theme()
sns.set(rc={"figure.dpi":200})
sns.set(rc={"figure.figsize":(6,3)})

sns.boxplot(x="Calories", y="Caffeine (mg)", data=df)
