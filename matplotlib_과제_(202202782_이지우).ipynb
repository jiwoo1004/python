# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwoo1004/python/blob/main/matplotlib_%EA%B3%BC%EC%A0%9C_(202202782_%EC%9D%B4%EC%A7%80%EC%9A%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 2, 0.0001)
y = x**2 + np.sin(3*x+7)
plt.plot(x,y)
plt.show()
